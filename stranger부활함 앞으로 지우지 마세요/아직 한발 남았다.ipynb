# %%
a = [1, 2, 3, 4, 5]

# %%
a[1:3]
# Out:
# [2, 3]

# %%
a[4] = 6
print(a[4])
# Out:
# 6

# %%
a = [1, 2, 3, 4, 5]
b = [6, 7, 8]
print(a + b)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
python = "..."

# %%
b = len(a) + 6
print(b)
# Out:
# 451624

# %%
a.append(6)

# %%
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a.insert(2, 2.5)

# %%
del a[1]
del a[1]

# %%
a.remove(4)

# %%
a.pop()
# Out:
# 5

# %%
a = [1, 2, 3, 4, 5]

# %%
test = [1, 2, 3, ["a", "b", "c"], 4, 5]

# %%
test[3][1]
# Out:
# 'b'

# %%
s = [1, 4, 3, 2]
s.sort()
s
# Out:
# [1, 2, 3, 4]

# %%
abc = ["a", "c", "b", "d"]
abc.sort()
abc.reverse()
abc
# Out:
# ['d', 'c', 'b', 'a']

# %%
가나다 = ["가", "나", "라", "다"]
가나다.sort()
가나다.reverse()
가나다
# Out:
# ['라', '다', '나', '가']

# %%
point
# Out:
# Point(x=452, y=500)

# %%
import pyautogui as pt

pt.moveTo(657, 755, 1)
pt.click()
time.sleep(3)
scratch = pt.locateOnScreen("스크래치.png")
point = pt.center(scratch)
pt.click(point.x,point.y,1)
time.sleep(5)
explore = pt.locateOnScreen("탐험하기.png")
point2 = pt.center(explore)
pt.click(point2)
time.sleep(2)
game = pt.locateOnScreen("게임.png")
point3 = pt.center(game)
pt.click(point3)
time.sleep(2)
game2 = pt.locateOnScreen("project.png")
point4 = pt.center(game2)
pt.click(point4)
time.sleep(10)
gameplay = pt.locateOnScreen("start.png")
point5 = pt.center(gameplay)
pt.click(point5)

# %%
import time
time.sleep(3)
print(scratch)
# Out:
# None

# %%
pt.position()
# Out:
# Point(x=657, y=755)
